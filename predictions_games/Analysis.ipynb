# %%
import numpy as np
from scipy import stats
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("inning_simulation24.csv")

# %%
np.mean(df["ERA"])
# Out:
# 4.307

# %%
df_zeros = df.loc[df['Third of Pitcher'] == 0]
np.mean(df_zeros["ERA"])
# Out:
# 4.125000000000001

# %%
df2 = pd.read_csv("../PitcherPolicy-Inning/Data/2015-2018_atbats.csv")

# %%
kernel = stats.gaussian_kde(df['ERA'])
positions = [x / 100.0 for x in range(100,800)]
Z = kernel(positions)
plt.plot(positions, Z)
plt.show()

# %%
np.var(df["ERA"])
# Out:
# 0.6145309999999999

# %%
plt.plot(positions, Z)
plt.show()
